# %%
"Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo".upper()
# Out:
# 'HOLA MUNDO'

# %%
"Hola Mundo".lower()
# Out:
# 'hola mundo'

# %%
"Hola Mundo".capitalize()
# Out:
# 'Hola mundo'

# %%
"Hola Mundo".title()
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo".count('o')
# Out:
# 2
